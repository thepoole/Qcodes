# %% [markdown]
# # Logging
# (back to the overview [offline](../Main.ipynb),[online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/Main.ipynb))
#
# [read on nbviewer](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logging_example.ipynb)

# %% [markdown]
# ## TL;DR
#  * There is a QCoDeS logging module: `qcodes.utils.logger`
#  * Call `logger.start_all_logging` at the start of every script/session to make sure all log messages get stored to the `.qcodes/logs` folder in your home directory, or set `logger.start_logging_on_import` to `True` in your `qcodesrc.json` configuration.
#  * For debugging purposes you can log messages of an individual instrument (and see the VISA dialog).
#  * You can obtain all logging messages in a `pandas.DataFrame` for further analysis.

# %% [markdown]
# ## Contents
# - [Introduction](#Introduction)
# - [Set up logging in QCoDeS](#Set-up-logging-in-QCoDeS)
#   - [QCoDeS default handlers](#QCoDeS-default-handlers)
#   - [IPython command history](#IPython-command-history)
# - [Temporarily elevating the logging level](#Temporarily-elevating-the-logging-level)
# - [Filtering log messages by instrument](#Filtering-log-messages-by-instrument)
# - [Capturing Pandas.DataFrame](#Capturing-Pandas.DataFrame)

# %% [markdown]
# ## Introduction
# Python offers an excellent logging framework that is widely used in QCoDeS. As a user, you might be interested in reading the log messages that are generated by QCoDeS for debugging and also profiling purposes.
#
# All log records(i.e., messages and metadata) are created using a python `logging.logger` object. In QCoDeS there is a logger for every module with the same name as the module itself, i.e., you can use `logging.getLogger('qcodes.instrument.base')` for getting the logger of the QCoDeS `Instrument`. From the dots in the names of the loggers a hierarchy is defined, at the top of which is the so called *root logger* that catches all messages.
# The log records created in a logger are processed by the *handlers* that have been attached to this specific *logger*.
# The handlers can, for example, be used to output the log messages into different locations, like the console or a log file.
#
# Every logger, handler and log record has an associated level. The default levels are: `CRITICAL`, `ERROR`, `WARNING`, `INFO` and `DEBUG`. The levels determine how messages are passed: a logger passes only records that exceeds its minimal passing level to its handlers and the handlers in turn only output those messages that exceed their minimal passing level.
#
#
# For a more detailed description of Python logging refer to the [official manual](https://docs.python.org/3.6/library/logging.html#module-logging) (This is all well summed up [in this chart](https://docs.python.org/3.6/howto/logging.html#logging-flow))

# %% [markdown]
# ## Instrument communication loggers
# Not all the used loggers in QCoDeS follow the previously presented rule of naming the logger after the module. For instruments there are the following loggers:
#  - **qcodes.instrument.base.com**:
#    This logger logs all the communication of the `Instrument` and its descendants with the actual physical instruments, e.g.,  the messages generated by the `write` and `query` calls.
#  - **qcodes.instrument.base.com.visa**:
#   This is a sublogger that logs all the communication related messages of the `VisaInstrument` and its descendants.

# %% [markdown]
# ## Set up logging in QCoDeS
# At the beginning of every experiment script file you should include the following lines:

# %%
from qcodes.logger import start_all_logging
start_all_logging()
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : /home/runner/.qcodes/logs/command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : /home/runner/.qcodes/logs/211123-19555-qcodes.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : /home/runner/.qcodes/logs/command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : /home/runner/.qcodes/logs/211123-19555-qcodes.log

# %% [markdown]
# The call to `start_all_logging` does two things:
# 1. Create handlers to output logging messages from the root logger to the console and to a log file.
# 2. Enable logging of the IPython commands into a separate log file.

# %% [markdown]
# Alternatively we can configure qcodes to automatically start logging on every import of qcodes, by running the following code once. (This will persist the current configuration in `~\qcodesrc.json`)

# %%
from qcodes import config
config.logger.start_logging_on_import = 'always'
config.save_to_home()

# %% [markdown]
# ### QCoDeS default handlers
# The effect of the console handler can be seen in the two printed lines with a red background below the previous code cell. Every line corresponds to a log record. The fields of the records are separated by `¦` and have the following meaning:
#  0. time stamp
#  1. logger name, here the module name
#  2. record log level
#  3. name of the function that created the log message
#  4. line at which the message has been issued
#  5. actual log message
#
# The same format is used for the file handler. By default QCoDeS logs to the file `<user directory>/.qcodes/logs/qcodes.log`. To avoid endlessly long files, the files roll over at midnight and get the date appended to their name where `qcodes.log` without date always gives you the log messages of the same day.
#
# To configure the levels you want to log/handle, you need to edit the `qcodesrc.json` file in you home directory. The default values are:
# ```
#     "logger":{
#         "console_level": "WARNING",
#         "file_level": "INFO",
#         "logger_levels":{
#             "pyvisa": "INFO"
#         }
# ```
# While `console_level` and `file_level` describe the levels of the two default handlers described previously, `logger_levels` is a dictionary that can be used to limit the messages passed on by module level loggers. This means with these defaults, the `pyvisa` module will not log messages on a `DEBUG` level. Therefore setting the `console_level` to `DEBUG` will not show the `pyvisa` debug messages (you certainly don't want to see them as they log every single character that is passed to an instrument with an individual message). On the other hand setting the console level to warning will still suppress `pyvisa` info messages.

# %% [markdown]
# ### IPython command history
# The output above that follows these logging messages comes from IPython. It tells us that all issued IPython commands will be logged to a file. The file lives in the same log directory as the python logs and is called `command_history.log`. It will not roll over.
#
# To change the command history logging directory you will need to call `start_command_history_logger` with the new path as an argument.

# %% [markdown]
# ## Temporarily elevating the logging level
# Sometimes you might wish to catch more than that meets to the eye. To this end, one can temporarily elevate the logging level to catch all debug messages by using a context manager. This can simply be done via:

# %%
import logging
import qcodes.logger as logger
log = logging.getLogger('example_logger')

log.debug('This message will not be visible as the logging level is set to `DEBUG`')

with logger.console_level(logging.DEBUG):
    log.debug('This message is visible as the logging level is temporarily elevated to `DEBUG`')
    
log.debug('The level is back to what it used to be')
# Out:
# 2021-11-23 17:58:12,054 ¦ example_logger ¦ DEBUG ¦ 4053955214 ¦ <module> ¦ 8 ¦ This message is visible as the logging level is temporarily elevated to `DEBUG`

# %% [markdown]
# For other handlers than the console handler, you can do the same thing using the `handler_level` context manager.

# %% [markdown]
# ## Filtering log messages by instrument
# A very common use case for logging in QCoDeS is to analyze the communication with a VISA instrument. For this purpose the logger module provides a context manager to filter the logging messages by instrument.
#
# Generally one could of course simply attach a handler to the logger of `qcodes.instrument_drivers.Vendor.Type` but this would not show the messages that are generated by the visa communication in `qcodes.instrument.visa`. Additionally with the approach implemented here one can not only filter messages for a given type of instrument but also of a specific instance.
#
# To demonstrate this consider the following mock up of the AMI430 Magnet controller that consists of individual VISA instruments for each axis, here with the names `x`, `y` and `z`:

# %%
from qcodes.instrument.ip_to_visa import AMI430_VISA
from qcodes.instrument_drivers.american_magnetics.AMI430 import AMI430_3D, AMI430Warning

import qcodes.instrument.sims as sims

visalib = sims.__file__.replace('__init__.py', 'AMI430.yaml@sim')

mag_x = AMI430_VISA('x', address='GPIB::1::INSTR', visalib=visalib,
                        terminator='\n', port=1)
mag_y = AMI430_VISA('y', address='GPIB::2::INSTR', visalib=visalib,
                        terminator='\n', port=1)
mag_z = AMI430_VISA('z', address='GPIB::3::INSTR', visalib=visalib,
                        terminator='\n', port=1)

import numpy as np
field_limit = [
    lambda x, y, z: x == 0 and y == 0 and z < 3,
    lambda x, y, z: np.linalg.norm([x, y, z]) < 2
]

driver = AMI430_3D("AMI430-3D", mag_x, mag_y, mag_z, field_limit)
# Out:
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.04s
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.00s
# Connected to: QCoDeS AMI430_simulation (serial:1337, firmware:0.0.01) in 0.00s

# %% [markdown]
# In the above messages you can see the prefix `[<instrument_name>(<instrument_type>)]`. To analyze the visa communication one can use `filter_instrument`:

# %%
driver.cartesian((0, 0, 0))
with logger.console_level('DEBUG'):
    with logger.filter_instrument(mag_x):
        driver.cartesian((0, 0, 1))
# Out:
# 2021-11-23 17:58:12,141 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [x(AMI430_VISA)] Querying: STATE?
# 2021-11-23 17:58:12,142 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [x(AMI430_VISA)] Response: 2
# 2021-11-23 17:58:12,143 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2021-11-23 17:58:12,144 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [x(AMI430_VISA)] Response: 0.0
# 2021-11-23 17:58:12,145 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2021-11-23 17:58:12,147 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [x(AMI430_VISA)] Response: 0.0

# %% [markdown]
# The output on the console shows as expected only messages from the `x` instrument. For multiple instruments pass a sequence of instruments to `filter_instrument` we write:

# %%
driver.cartesian((0, 0, 0))
with logger.console_level('DEBUG'):
    with logger.filter_instrument((mag_x, mag_y)):
        driver.cartesian((0, 0, 1))
# Out:
# 2021-11-23 17:58:12,163 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [x(AMI430_VISA)] Querying: STATE?
# 2021-11-23 17:58:12,164 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [x(AMI430_VISA)] Response: 2
# 2021-11-23 17:58:12,165 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [y(AMI430_VISA)] Querying: STATE?
# 2021-11-23 17:58:12,165 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [y(AMI430_VISA)] Response: 2
# 2021-11-23 17:58:12,166 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2021-11-23 17:58:12,167 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [x(AMI430_VISA)] Response: 0.0
# 2021-11-23 17:58:12,168 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [y(AMI430_VISA)] Querying: FIELD:MAG?
# 2021-11-23 17:58:12,168 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [y(AMI430_VISA)] Response: 0.0
# 2021-11-23 17:58:12,169 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [x(AMI430_VISA)] Querying: FIELD:MAG?
# 2021-11-23 17:58:12,175 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [x(AMI430_VISA)] Response: 0.0
# 2021-11-23 17:58:12,175 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 234 ¦ [y(AMI430_VISA)] Querying: FIELD:MAG?
# 2021-11-23 17:58:12,176 ¦ qcodes.instrument.base.com.visa ¦ DEBUG ¦ visa ¦ ask_raw ¦ 236 ¦ [y(AMI430_VISA)] Response: 0.0

# %% [markdown]
# ## Capturing Pandas.DataFrame
# To process the logs, especially with the timestamps, the [pandas module](https://pandas.pydata.org/) is highly suited. With `logger.log_to_dataframe` or `logger.logfile_to_dataframe` you can convert a log(file) to a pandas `DataFrame`. See this ([online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logfile_parsing.ipynb), [offline](logfile_parsing.ipynb)) notebook for an example.
#
# You can also use a context manager to capture the logs directly into a `DataFrame`.

# %%
from qcodes.logger.log_analysis import capture_dataframe

# %%
with logger.console_level(logging.WARN):
    driver.cartesian((0, 0, 0))
    with capture_dataframe(level='DEBUG') as (handler, get_dataframe):
        driver.cartesian((0, 0, 1))
        df = get_dataframe()
        driver.cartesian((0, 0, 2))
        df2 = get_dataframe() # this is the cummulative log

# %%
df
# Out:
#                     asctime                             name levelname  \
# 0   2021-11-23 17:58:12,198           qcodes.instrument.base     DEBUG
# 1   2021-11-23 17:58:12,198  qcodes.instrument.base.com.visa     DEBUG
# 2   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 3   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 4   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 5   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 6   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 7   2021-11-23 17:58:12,199           qcodes.instrument.base     DEBUG
# 8   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 9   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 10  2021-11-23 17:58:12,200  qcodes.instrument.base.com.visa     DEBUG
# 11  2021-11-23 17:58:12,200  qcodes.instrument.base.com.visa     DEBUG
# 12  2021-11-23 17:58:12,200  qcodes.instrument.base.com.visa     DEBUG
# 13  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 14  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 15  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 16  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 17  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 18  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 19  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 20  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 21  2021-11-23 17:58:12,201  qcodes.instrument.base.com.visa     DEBUG
# 22  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 23  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 24  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 25  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 26  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 27  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 28  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 29  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 30  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 31  2021-11-23 17:58:12,202  qcodes.instrument.base.com.visa     DEBUG
# 32  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 33  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 34  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 35  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 36  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 37  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 38  2021-11-23 17:58:12,203  qcodes.instrument.base.com.visa     DEBUG
# 39  2021-11-23 17:58:12,203           qcodes.instrument.base     DEBUG
# 40  2021-11-23 17:58:12,204  qcodes.instrument.base.com.visa     DEBUG
# 41  2021-11-23 17:58:12,204  qcodes.instrument.base.com.visa     DEBUG
# 42  2021-11-23 17:58:12,204  qcodes.instrument.base.com.visa     DEBUG
# 43  2021-11-23 17:58:12,204  qcodes.instrument.base.com.visa     DEBUG
# 44  2021-11-23 17:58:12,204           qcodes.instrument.base     DEBUG
#
#     module                   funcName lineno  \
# 0   AMI430  _adjust_child_instruments    909
# 1     visa                    ask_raw    234
# 2     visa                    ask_raw    236
# 3     visa                    ask_raw    234
# 4     visa                    ask_raw    236
# 5     visa                    ask_raw    234
# 6     visa                    ask_raw    236
# 7   AMI430  _adjust_child_instruments    925
# 8     visa                    ask_raw    234
# 9     visa                    ask_raw    236
# 10    visa                    ask_raw    234
# 11    visa                    ask_raw    236
# 12    visa                    ask_raw    234
# 13    visa                    ask_raw    236
# 14    visa                    ask_raw    234
# 15    visa                    ask_raw    236
# 16    visa                    ask_raw    234
# 17    visa                    ask_raw    236
# 18    visa                    ask_raw    234
# 19    visa                    ask_raw    236
# 20    visa                    ask_raw    234
# 21    visa                    ask_raw    236
# 22    visa                    ask_raw    234
# 23    visa                    ask_raw    236
# 24    visa                    ask_raw    234
# 25    visa                    ask_raw    236
# 26    visa                    ask_raw    234
# 27    visa                    ask_raw    236
# 28    visa                    ask_raw    234
# 29    visa                    ask_raw    236
# 30    visa                  write_raw    220
# 31    visa                  write_raw    220
# 32    visa                    ask_raw    234
# 33    visa                    ask_raw    236
# 34    visa                    ask_raw    234
# 35    visa                    ask_raw    236
# 36    visa                    ask_raw    234
# 37    visa                    ask_raw    236
# 38    visa                  write_raw    220
# 39  AMI430                  set_field    358
# 40    visa                    ask_raw    234
# 41    visa                    ask_raw    236
# 42    visa                    ask_raw    234
# 43    visa                    ask_raw    236
# 44  AMI430                  set_field    360
#
#                                               message
# 0   [AMI430-3D(AMI430_3D)] Checking whether fields...
# 1                   [x(AMI430_VISA)] Querying: STATE?
# 2                        [x(AMI430_VISA)] Response: 2
# 3                   [y(AMI430_VISA)] Querying: STATE?
# 4                        [y(AMI430_VISA)] Response: 2
# 5                   [z(AMI430_VISA)] Querying: STATE?
# 6                        [z(AMI430_VISA)] Response: 2
# 7   [AMI430-3D(AMI430_3D)] Field values OK, procee...
# 8               [x(AMI430_VISA)] Querying: FIELD:MAG?
# 9                      [x(AMI430_VISA)] Response: 0.0
# 10              [y(AMI430_VISA)] Querying: FIELD:MAG?
# 11                     [y(AMI430_VISA)] Response: 0.0
# 12              [z(AMI430_VISA)] Querying: FIELD:MAG?
# 13                     [z(AMI430_VISA)] Response: 0.0
# 14              [x(AMI430_VISA)] Querying: FIELD:MAG?
# 15                     [x(AMI430_VISA)] Response: 0.0
# 16              [y(AMI430_VISA)] Querying: FIELD:MAG?
# 17                     [y(AMI430_VISA)] Response: 0.0
# 18              [z(AMI430_VISA)] Querying: FIELD:MAG?
# 19                     [z(AMI430_VISA)] Response: 0.0
# 20                   [z(AMI430_VISA)] Querying: COIL?
# 21                     [z(AMI430_VISA)] Response: 2.0
# 22             [z(AMI430_VISA)] Querying: CURR:LIMIT?
# 23                      [z(AMI430_VISA)] Response: 80
# 24                     [z(AMI430_VISA)] Querying: QU?
# 25                       [z(AMI430_VISA)] Response: 0
# 26                   [z(AMI430_VISA)] Querying: PERS?
# 27                       [z(AMI430_VISA)] Response: 0
# 28                  [z(AMI430_VISA)] Querying: STATE?
# 29                       [z(AMI430_VISA)] Response: 2
# 30                    [z(AMI430_VISA)] Writing: PAUSE
# 31      [z(AMI430_VISA)] Writing: CONF:FIELD:TARG 1.0
# 32                [z(AMI430_VISA)] Querying: PS:INST?
# 33                   [z(AMI430_VISA)] Response: ERROR
# 34                [z(AMI430_VISA)] Querying: PS:INST?
# 35                   [z(AMI430_VISA)] Response: ERROR
# 36                     [z(AMI430_VISA)] Querying: PS?
# 37                       [z(AMI430_VISA)] Response: 0
# 38                     [z(AMI430_VISA)] Writing: RAMP
# 39  [z(AMI430_VISA)] Starting blocking ramp of z t...
# 40                  [z(AMI430_VISA)] Querying: STATE?
# 41                       [z(AMI430_VISA)] Response: 2
# 42                  [z(AMI430_VISA)] Querying: STATE?
# 43                       [z(AMI430_VISA)] Response: 2
# 44            [z(AMI430_VISA)] Finished blocking ramp

# %%
df2
# Out:
#                     asctime                             name levelname  \
# 0   2021-11-23 17:58:12,198           qcodes.instrument.base     DEBUG
# 1   2021-11-23 17:58:12,198  qcodes.instrument.base.com.visa     DEBUG
# 2   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 3   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# 4   2021-11-23 17:58:12,199  qcodes.instrument.base.com.visa     DEBUG
# ..                      ...                              ...       ...
# 85  2021-11-23 17:58:12,291  qcodes.instrument.base.com.visa     DEBUG
# 86  2021-11-23 17:58:12,291  qcodes.instrument.base.com.visa     DEBUG
# 87  2021-11-23 17:58:12,291  qcodes.instrument.base.com.visa     DEBUG
# 88  2021-11-23 17:58:12,291  qcodes.instrument.base.com.visa     DEBUG
# 89  2021-11-23 17:58:12,291           qcodes.instrument.base     DEBUG
#
#     module                   funcName lineno  \
# 0   AMI430  _adjust_child_instruments    909
# 1     visa                    ask_raw    234
# 2     visa                    ask_raw    236
# 3     visa                    ask_raw    234
# 4     visa                    ask_raw    236
# ..     ...                        ...    ...
# 85    visa                    ask_raw    234
# 86    visa                    ask_raw    236
# 87    visa                    ask_raw    234
# 88    visa                    ask_raw    236
# 89  AMI430                  set_field    360
#
#                                               message
# 0   [AMI430-3D(AMI430_3D)] Checking whether fields...
# 1                   [x(AMI430_VISA)] Querying: STATE?
# 2                        [x(AMI430_VISA)] Response: 2
# 3                   [y(AMI430_VISA)] Querying: STATE?
# 4                        [y(AMI430_VISA)] Response: 2
# ..                                                ...
# 85                  [z(AMI430_VISA)] Querying: STATE?
# 86                       [z(AMI430_VISA)] Response: 2
# 87                  [z(AMI430_VISA)] Querying: STATE?
# 88                       [z(AMI430_VISA)] Response: 2
# 89            [z(AMI430_VISA)] Finished blocking ramp
#
# [90 rows x 7 columns]

# %% [markdown]
# You can of course combine the context managers:

# %%
with logger.console_level(logging.WARN):
    driver.cartesian((0, 0, 0))
    with capture_dataframe(level='DEBUG') as (handler, get_dataframe):
        with logger.filter_instrument(mag_x, handler=handler):
            driver.cartesian((0, 0, 1))
            df = get_dataframe()
df
# Out:
#                    asctime                             name levelname module  \
# 0  2021-11-23 17:58:12,342  qcodes.instrument.base.com.visa     DEBUG   visa
# 1  2021-11-23 17:58:12,342  qcodes.instrument.base.com.visa     DEBUG   visa
# 2  2021-11-23 17:58:12,342  qcodes.instrument.base.com.visa     DEBUG   visa
# 3  2021-11-23 17:58:12,343  qcodes.instrument.base.com.visa     DEBUG   visa
# 4  2021-11-23 17:58:12,343  qcodes.instrument.base.com.visa     DEBUG   visa
# 5  2021-11-23 17:58:12,343  qcodes.instrument.base.com.visa     DEBUG   visa
#
#   funcName lineno                                message
# 0  ask_raw    234      [x(AMI430_VISA)] Querying: STATE?
# 1  ask_raw    236           [x(AMI430_VISA)] Response: 2
# 2  ask_raw    234  [x(AMI430_VISA)] Querying: FIELD:MAG?
# 3  ask_raw    236         [x(AMI430_VISA)] Response: 0.0
# 4  ask_raw    234  [x(AMI430_VISA)] Querying: FIELD:MAG?
# 5  ask_raw    236         [x(AMI430_VISA)] Response: 0.0

# %% [markdown]
# For an analysis of the timestamps please also refer to the log analysis example notebook ([online](https://nbviewer.jupyter.org/github/QCoDeS/Qcodes/tree/master/docs/examples/logging/logfile_parsing.ipynb), [offline](logfile_parsing.ipynb)).
